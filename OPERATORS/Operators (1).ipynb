# %%
a = 5
b = 3
c=a+b
print(c)
# Out:
# 8

# %%
a-b
# Out:
# 2

# %%
a*b
# Out:
# 15

# %% [markdown]
# Assignment Operator

# %%
#.     =, +=, -=

# %%
a=5
b=4

# %%
a=5
b=4

# %%
x = 20
x +=20

x = x+20


print(x)
# Out:
# 40

# %%
# +=
x = 5
x += 5
print(x)
# Out:
# 10

# %%
# -=
x = 20
x -= 20
print(x)
# Out:
# 0

# %% [markdown]
# COMPARISON OPERATOR

# %% [markdown]
# Equal Operator x==y
#
# Not Equal X!=
#
# Greater Than x>y
#
# Less than x<y
#
# Greater than or equal to >=
#
# Less than or equal to <=

# %%
x = 90
y = 20
print(x <= y)
# Out:
# False

# %%
a = 'shinas'
b = 32
if type(a) == type(b)
# Out:
#   File "<ipython-input-15-d044e4987f7c>", line 3
#     if type(a) == type(b)
#                          ^
# SyntaxError: expected ':'

# %%
a= 'shinas'
b = 32
if type(a) == type(b)
  print("the data types are similar:");
# Out:
#   File "<ipython-input-18-9c60c98a65e4>", line 3
#     if type(a) == type(b)
#                          ^
# SyntaxError: expected ':'

# %%
a = 'shinas'
b = 43
a == 'b'
type(x) == type(y)
# Out:
# True

# %% [markdown]
# LOGICAL OPERATORS

# %%
True and False
# Out:
# False

# %%
True and True
# Out:
# True

# %%
a = 40
b = 50
Is a>b and b>a
# Out:
#   File "<ipython-input-30-0257639beaa7>", line 3
#     Is a>b and b>a
#        ^
# SyntaxError: invalid syntax

# %%
a = 10
b = 5
Is 10 > 5 and 5 < 7
# Out:
#   File "<ipython-input-34-1124f6f1c777>", line 3
#     Is 10 > 5 and 5 < 7
#        ^
# SyntaxError: invalid syntax

# %%
False and True
# Out:
# False

# %%
x = 90
y = 20
print(not x == y and x!=y)
# Out:
# True

# %% [markdown]
# Identity Operators
# is
# is not

# %%
a = 43
b = 93
print(a is b)
# Out:
# False

# %%
a = 32
b = 23
print(type(a) is type(b))
# Out:
# True

# %% [markdown]
# Membership Operator
#
# in
#
# not in

# %%
x = 'shinas'
print('a' in x)
# Out:
# True

# %%
x = 'hey'
print('e' not in x)
# Out:
# False

# %% [markdown]
# Collection Data Types--acts as a container for collection of data
#
# List
#
# Range
#
# Tuple
#
# List
#
# List is a ordered sequence
#
# List is a mutable collection of data
#
# Theoritically of infinte length
#
# List is a iteratble
#
# Allow duplicate members
#
# Return in square brackets

# %%
list1 = ['shinas','rejath','adith',40]
print(list1)
# Out:
# ['shinas', 'rejath', 'adith', 40]

# %% [markdown]
# Nested list
#
# List within the list

# %%
list1 = ['shinas','hey','kelvin',[]'who',32]]
print(list1)
# Out:
#   File "<ipython-input-9-6988ef39b656>", line 1
#     list1 = ['shinas','hey','kelvin',[]'who',32]]
#                                                 ^
# SyntaxError: unmatched ']'

# %%
list1 = ['shinas','hey']
print(list1)
# Out:
# ['shinas', 'hey']

# %% [markdown]
# Indexing and slicing
#
# Postive Indexing--Forward Indexing
#
#
# Negative Indexing-Backward Indexing

# %%
list1 = ['shinas','rejath','adith','akash']
print(list1[-2])
# Out:
# adith

# %% [markdown]
# Slicing--returns a slice object

# %%
list1 = ['shinas','rejath','jacob']
print(list1[0:2])
# Out:
# ['shinas', 'rejath']

# %%
list1 = [['raju',30],['ramu'],'dolu','bolu','bolu']

print(list1[-4:-1])
# Out:
# [['ramu'], 'dolu', 'bolu']

# %% [markdown]
# List Swapping

# %%
list1 =['shinas','rejath','adith','akash','vaishnav']
list1[3],list1[1] = list1[1],list1[3]
print(list1)
# Out:
# ['shinas', 'akash', 'adith', 'rejath', 'vaishnav']

# %%
list1 = ['raju','ramu','dolu','radha','bolu']
list1[0],list1[2] = list1[2],list1[0]
list1[1]list1[3] = list1[3],list1[1]
# Out:
# ['dolu', 'ramu', 'raju', 'radha', 'bolu']

# %%
list1 = ['sonu','adwith','sanjay']

list1.extend(['shinas','ram'])

print(list1)
# Out:
# ['sonu', 'adwith', 'sanjay', 'shinas', 'ram']

# %%
list1 = [34,54,22,42,11,25,64,21,100,11]
print(max(list1))
print(sum(list1))
# Out:
# 100
# 384

# %% [markdown]
# Tuple---used to record
#
# Tuple is ordered sequence
#
# Tuple is inmutable
#
# Infinite Length
#
# Iterable
#
# Allows Duplicate Members
#
# Parenthesis brackets ()

# %%
#tuple creation

tuple1 = ('raju','ramu','dolu','bolu')

print(type(tuple1))
# Out:
# <class 'tuple'>

# %%
tuple2 = (34,41,24,55,32,21)

print(tuple2.index(24))
# Out:
# 2

# %% [markdown]
# Range
#
# START VALUE=96
#
# END VALUE=71
#
# STEP VALUE=-4

# %%
x = range(96,71,-4)

print(x)
# Out:
# range(96, 71, -4)

# %% [markdown]
# Methods using in list

# %% [markdown]
# SET -- NOT ORDERED
#
# FROZEN SET

# %% [markdown]
# String
#
# find method--to indicate the position

# %%
string1 = 'hello raju how are you raju'

print(string1.rfind('raju'))
# Out:
# 23

# %% [markdown]
# String Split

# %%
string1 = 'hello raju how are you'

stringlist = string1.split(' ')

print(stringlist)
# Out:
# ['hello', 'raju', 'how', 'are', 'you']

# %%
string1 = ['hello','raju','how','are','you']

stringlist = ' '.join(string1)

print(stringlist)
# Out:
# hello raju how are you

# %%
string1 = 'hello raju how are you raju'

string1 = string1.capitalize()

print(string1)
# Out:
# Hello raju how are you raju

# %% [markdown]
# string1 = string1.upper()
#
# string1 = string1.lower()
#
# string1 = string.title()
#
# isalnum --alphabets and numeric
#
# istitle -- whether all are in title
#
# isdigit()
#
# islower()
#
# isalpha()

# %%
string1 = 'heyshinashowareyou323'

string1 = string1.isalnum()

print(string1)
# Out:
# True

# %%
string1 = '2132231'

string1 = string1.isdigit()

print(string1)
# Out:
# True

# %%
string1 = 'ABDAREWRE'
string1 = string1.isupper()
print(string1)
# Out:
# True

# %% [markdown]
# Conditions

# %% [markdown]
# Set
#
# Not Ordered
#
# immutable
#
# infinite length
#
# iterable
#
# allows duplicate members
#
# distinct elements
#
# {}

# %%
names = {'ramu','raju','bolu','dolu'}



names.clear()

print(names)
# Out:
# set()

# %% [markdown]
# Union of two sets
