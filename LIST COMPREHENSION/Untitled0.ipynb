# %%
def myfunc():
  global x

  x = 300

myfunc()

print(x)
# Out:
# 300

# %%
def myfunc():
  x = 300
  def myinnerfunc():
    print(x)
  myinnerfunc()

myfunc()
print(x)
# Out:
# 300
# 300

# %%
x = 300

def myfunc():
  global x
  x = 200

myfunc()

print(x)
# Out:
# 200
