# %% [markdown]
# Lambda Functions are similar to user defined functions but without a name
#
# They're commonly referred to as anonymous functions.
#
# Syntax:
#
# lambda argument(s):expression
#
# lambda is a keyword in Python for defining the anonymous function
#
# argument(s)is a placeholder,that is a variable that will be used to hold the
#
# value you want to pass into the function expression.A lambda function can
#
# have multiple variables depending on what you want to acheive.
#
# expression is the code you want to execute in the lambda function

# %%
#hello
OLLEH

# %%
#user defined function
def functionnames(n1,n2):

  expression

  return expression

# %%
def exp(x):

  return x**2

exp(5)
# Out:
# 25

# %%
x = lambda x : x **2

print(x(4))
# Out:
# 16

# %%
print((lambda x:x**2)(4))
# Out:
# 16

# %%
x = lambda x : x.upper()[::-1]

print(x('hello'))
# Out:
# OLLEH

# %%
x = lambda x,y : x-y if x>y else y-x

print(x(2,4))
# Out:
# 2

# %% [markdown]
# n1,n2
#
# n1-n2
#
# n2-n1

# %%
x = lambda x,y : x-y if x>y else y - x

print(x(2,3))
# Out:
# 1

# %%
x = lambda x: "even" if x%2==0 else "odd"

print(x(5))
# Out:
# odd

# %% [markdown]
# Filter():
#
# The filer function operator on a list and returns a subset of that list after
#
# applying the filter rule.The function filter(f,I)needs a function f as it
#
# arguments.f returns a Boolean value ie either true or false.this function
#
# will be applied to every element of the list I. only if f returns True will
#
# element of the list I.only if f returns True will the element of the list be
#
# included in the result list

# %%
list1 = [2,4,5,6,7,8,12,13,15,11]

# %%
x = filter(lambda x : x%2==0,list1)

# %%
print((x))
# Out:
# <filter object at 0x7a17bab7c3a0>

# %%
print(list(x))
# Out:
# [2, 4, 6, 8, 12]

# %%
print(list(filter(lambda x : x%2==0,list1)))
# Out:
# [2, 4, 6, 8, 12]

# %%
list1 = ['raju','ramu','dolu','rema','bolu','arun']

print(list(filter(lambda x:x[0]=='r',list1)))
# Out:
# ['raju', 'ramu', 'rema']

# %% [markdown]
# map():
#
# The map()transforms a given list in to a new list by transforming each element
#
# using a rule,it is used to apply a function to each element of a list or any
#
# other iterable
#
# This is very useful when we do vector mathematics,the map()function will take
#
# multiple list operates on then and return the output list,one thing to note is
#
# that all the list should be of the same size because map() applies the
#
# function to corresponding elements in those lists

# %% [markdown]
# map()
#
# You use the map()function whenever you want to modify every value in iterable

# %%
#syntax of map()
#print(list(map(f,list1)))

# %%
list1 = [2,3,4,1]

print(list(map(lambda x : x**2,list1)))
# Out:
# [4, 9, 16, 1]

# %%
x = 10

x = 'shinas'

# %%
list1 = ['raju','ramu','dolu','bolu','rema']

#list2 = [True,True,False,False,True]

list2 = list(map(lambda name: name.startswith('r'), list1))

print(list2)
# Out:
# [True, True, False, False, True]

# %% [markdown]
# Zip Function
#
# The zip() function take iterables(can be zero or more)makes iterator that
#
# aggregates elements based on the iterables passed,and returns an iterator or
#
# tuples
#
# syntax:
#
# zip(*iterables)

# %%
#[2,3,4],[3,2,3] = ((2,3),(3,2),(4,3))

# %%
#[2,3,4],[3,2,3],[2,1,4,5] = ((2,3,2),(3,4,1),(4,3,4))

# %%
#[2,3,4],['raju','bolu','dolu'] = ((2,'raju')),(3,'bolu'),(4,'dolu')

# %%
rn = [1,2,3]

name = ['raju','bolu','dolu']

data = list(zip(rn,name))

print(data)
# Out:
# [(1, 'raju'), (2, 'bolu'), (3, 'dolu')]

# %%
rn = [1,2,3]

name = ['raju','bolu','dolu']

data = tuple(zip(rn,name))

print(data)
# Out:
# ((1, 'raju'), (2, 'bolu'), (3, 'dolu'))

# %%
rn = [1,2,3]

name = ['raju','bolu','dolu']

data = dict(zip(rn,name))

print(data)
# Out:
# {1: 'raju', 2: 'bolu', 3: 'dolu'}

# %% [markdown]
# **Exception Handling**

# %%
num1 = int(input('num1'))
num2 = int(input('num2'))

num3 = num1/num2

print(num3)
# Out:
# num110
# num20
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-5-161122b98fc6> in <cell line: 4>()
#       2 num2 = int(input('num2'))
#       3
# ----> 4 num3 = num1/num2
#       5
#       6 print(num3)
#
# ZeroDivisionError: division by zero

# %%
num1 = int(input('num1'))
num2 = int(input('num2'))

num3 = num1/num2

print(num3)
# Out:
# num110
# num20
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-58-161122b98fc6> in <cell line: 4>()
#       2 num2 = int(input('num2'))
#       3
# ----> 4 num3 = num1/num2
#       5
#       6 print(num3)
#
# ZeroDivisionError: division by zero

# %%
num1 = int(input('num1'))
num2 = int(input('num2'))

num3 = num1/num2

print(num3)
# Out:
# num110
# num20
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-36-161122b98fc6> in <cell line: 4>()
#       2 num2 = int(input('num2'))
#       3
# ----> 4 num3 = num1/num2
#       5
#       6 print(num3)
#
# ZeroDivisionError: division by zero

# %%
num1 = int(input('num1'))
num2 = int(input('num2'))


try:
   num3 = num1/num2
   print(num3)

except:
  print('an error exist')
# Out:
# num140
# num20
# an error exist

# %%
num1 = int(input('num1'))
num2 = int(input('num2'))


try:
   num3 = num1/num2
   print(num3)

except Exception as v:
  print(v)
# Out:
# num110
# num20
# division by zero

# %%
num1 = int(input('num1'))
num2 = int(input('num2'))


try:
   num3 = num1/num2
   print(num3)

except ZeroDivisionError as z:
  print(z)
# Out:
# num110
# num20
# division by zero

# %%
num1 = int(input('num1'))
num2 = int(input('num2'))


try:
   num3 = num1/num2
   print(num3)

except ValueError as e:
  print(e)
#except Exception as v:
  #print(v)
# Out:
# num110
# num20
# division by zero

# %%
num1 = int(input('num1'))
num2 = int(input('num2'))


try:
   num3 = num1/num2
   print(num3)

except Exception as e:
  print(e)
# Out:
# num110
# num2s
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-1c8ae1671e1c> in <cell line: 2>()
#       1 num1 = int(input('num1'))
# ----> 2 num2 = int(input('num2'))
#       3
#       4
#       5 try:
#
# ValueError: invalid literal for int() with base 10: 's'

# %%
try:
   num1 = int(input('num1'))
   num2 = int(input('num2'))
   num3 = num1/num2
   print(num3)

except ValueError as e:
  print(e)
# Out:
# num110
# num2a
# invalid literal for int() with base 10: 'a'

# %%
try:
  num1 = int(input('num1'))
  num2 = int(input('num2'))
  num3 = num1/num2
  print(num3)

except Exception as e:
  print(e)

else:
  print('there is no error')

finally:
  print('completed')
# Out:
# num110
# num2q
# invalid literal for int() with base 10: 'q'
# completed
