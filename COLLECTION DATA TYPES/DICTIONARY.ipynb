# %% [markdown]
# DICTIONARY
#
# A dictionary is a collection which is ordered*, changeable and do not allow duplicates.
#
# mutable
#
# infinite length
#
# iterable
#
# key value pair
#
# value indexed by key

# %%
details = {'name':'sarang','rollno':12,'job':'engineer'}
print(details)
# Out:
# {'name': 'sarang', 'rollno': 12, 'job': 'engineer'}

# %%
print(type(details))
# Out:
# <class 'dict'>

# %%
details = {'name':'shinas','phonenumber':42132,'job':'trainer'}

# %%
print(details)
# Out:
# {'name': 'shinas', 'phonenumber': 42132, 'job': 'trainer'}

# %%
print(type(details))
# Out:
# <class 'dict'>

# %%
details1 = dict({'name':'shinas','phonenumber':42132,'job':'trainer'})

# %%
print(type(details1))
# Out:
# <class 'dict'>

# %% [markdown]
# we can pass list as value but not as key,
# set also we can pass as value
#
# but not as key
#
# all data types float string int complex we can pass as key

# %%
details = {(3,5):'shinas','phonenumber':42132,'job':'trainer'}

# %%
print(details)
# Out:
# {(3, 5): 'shinas', 'phonenumber': 42132, 'job': 'trainer'}

# %%
details = {{3,5}:'shinas','phonenumber':42132,'job':'trainer'}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-52edf98db494> in <cell line: 1>()
# ----> 1 details = {{3,5}:'shinas','phonenumber':42132,'job':'trainer'}
#
# TypeError: unhashable type: 'set'

# %% [markdown]
# we can only pass immutable datatypes as key

# %% [markdown]
# NEW DATA ADDING

# %%
details = {(3,4):'shinas','phonenumber':42132,'job':'trainer'}

# %%
details['age'] = 20

# %%
details['age'] = 10

# %%
details
# Out:
# {(3, 4): 'shinas', 'phonenumber': 42132, 'job': 'trainer', 'age': 10}

# %% [markdown]
# UPDATE

# %%
details = {'name':'shinas','phonenumber':42132,'job':'trainer'}

# %%
details['name'] = 'raju'

# %%
print(details)
# Out:
# {'name': 'raju', 'phonenumber': 42132, 'job': 'trainer'}

# %%
details
# Out:
# {'name': 'raju', 'phonenumber': 42132, 'job': 'trainer'}

# %%
details.update({"age":32})

# %%
details
# Out:
# {'name': 'raju', 'phonenumber': 42132, 'job': 'trainer', 'age': 32}

# %%
details.update({"name":'ram'})

# %%
details
# Out:
# {'name': 'ram', 'phonenumber': 42132, 'job': 'trainer', 'age': 32}

# %% [markdown]
# DELETE

# %%
del details['name']

# %%
details
# Out:
# {'phonenumber': 42132, 'job': 'trainer', 'age': 32}

# %%
details.pop('job')
# Out:
# 'trainer'

# %%
details
# Out:
# {'phonenumber': 42132, 'age': 32}

# %%
details.popitem()
# Out:
# ('age', 32)

# %%
details
# Out:
# {'phonenumber': 42132}

# %%
print(details['phonenumber'])
# Out:
# 42132

# %%
print(details.get('phonenumber'))
# Out:
# 42132

# %%
print(details.keys())
# Out:
# dict_keys(['phonenumber'])

# %%
print(details.values())
# Out:
# dict_values([42132])

# %% [markdown]
# **STRING OPERATIONS**

# %%
x = 'python is is a simple language'

print(len(x))
# Out:
# 30

# %%
print(x.count('is'))
# Out:
# 2

# %%
print(x.count('a'))
# Out:
# 3

# %% [markdown]
# STRING INDEXING

# %%
print(x[7])
# Out:
# i

# %%
print(x[-1])
# Out:
# e

# %%
print(x[6])

# %%
#concatenate method

# %%
x = 'python is a simple language'

y = ' also powerfull'

print(x + y)
# Out:
# python is a simple language also powerfull

# %%
a = 'python is a simple language' + ' also powerful'

# %%
print(a)
# Out:
# python is a simple language also powerful

# %% [markdown]
# **Substitution**

# %%
x = 'python is a simple language'

y = 'also powerful'

z = x.replace('simple','both simple and powerful')

# %%
print(z)
# Out:
# python is a both simple and powerful language

# %%
x.startswith('p')
# Out:
# True

# %%
x.startswith('is')
# Out:
# False

# %%
x.startswith('is',7,9)
# Out:
# True

# %%
x.endswith('is',2,9)
# Out:
# True

# %%
txt = "Hello, welcome to my world."

x = txt.endswith(".")

print(x)
# Out:
# True
