# %%
thistuple = tuple(("apple", "banana", "cherry"))
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry')

# %%
thistuple[0]
# Out:
# 'apple'

# %% [markdown]
# **Tuple allows only one argument at a time**

# %%
thistuple = tuple(("apple", "banana", "cherry"),("raj","ram","vijay"))
print(thistuple)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-fa12f545ca3a> in <cell line: 1>()
# ----> 1 thistuple = tuple(("apple", "banana", "cherry"),("raj","ram","vijay"))
#       2 print(thistuple)
#
# TypeError: tuple expected at most 1 argument, got 2
