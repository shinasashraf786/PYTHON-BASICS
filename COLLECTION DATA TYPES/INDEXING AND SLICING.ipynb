# %% [markdown]
# INDEXING

# %% [markdown]
# Positive Indexing and negative indexing

# %%
list1 = [['raju',30],['ramu'],'bolu','dolu','bolu']

# %%
print(list1[-2])
# Out:
# dolu

# %%
print(list1[0])
# Out:
# ['raju', 30]

# %%
list1[1]
# Out:
# ['ramu']

# %%
list1 = [['raju',30],['ramu'],'bolu','dolu','bolu']

# %%
print(list1[-3])
# Out:
# bolu

# %%
print(list1[-5])
# Out:
# ['raju', 30]

# %% [markdown]
# **SLICING**

# %%
print(list1[0:3])
# Out:
# [['raju', 30], ['ramu'], 'bolu']

# %%
print(list1[:3])
# Out:
# [['raju', 30], ['ramu'], 'bolu']

# %%
print(list1[0:2])
# Out:
# [['raju', 30], ['ramu']]

# %%
print(list1[:2])
# Out:
# [['raju', 30], ['ramu']]

# %%
print(list1[:])
# Out:
# [['raju', 30], ['ramu'], 'bolu', 'dolu', 'bolu']

# %%
print(list1[1:])
# Out:
# [['ramu'], 'bolu', 'dolu', 'bolu']

# %%
list1 = [['raju',30],['ramu'],'bolu','dolu','bolu']

# %%
print(list1[1:-1])
print(list1[-4:-1])
print(list1[1:4])
# Out:
# [['ramu'], 'bolu', 'dolu']
# [['ramu'], 'bolu', 'dolu']
# [['ramu'], 'bolu', 'dolu']

# %%
print(list1[-4:])
# Out:
# [['ramu'], 'bolu', 'dolu', 'bolu']

# %% [markdown]
# Append

# %%
list1 = ['ram','raju','ajay']

# %%
list1.append('sanay')

# %%
print(list1)
# Out:
# ['ram', 'raju', 'ajay', 'sanay']

# %%
list4 = ['sanay','shinas','faiz']

# %%
list4.append('ajay')

# %%
print(list4)
# Out:
# ['sanay', 'shinas', 'faiz', 'ajay']

# %% [markdown]
# **Extend**

# %%
list4 = ['sanay','shinas','faiz']

# %%
list4
# Out:
# ['sanay', 'shinas', 'faiz']

# %%
list4.extend(['sahal','sanju'])

# %%
list4
# Out:
# ['sanay', 'shinas', 'faiz', 'sahal', 'sanju']

# %% [markdown]
# Insert

# %%
list4.insert(2,'anjal')

# %%
list4
# Out:
# ['sanay', 'shinas', 'anjal', 'faiz', 'sahal', 'sanju']

# %%
list4.insert(1,'rahul')

# %%
list4
# Out:
# ['sanay', 'rahul', 'shinas', 'anjal', 'faiz', 'sahal', 'sanju']

# %%
#List Swapping

# %%
list1 = ['raju','ramu','dolu','radha','bolu']

# %%
list1[3],list1[1] = list1[1],list1[3]

# %%
list1
# Out:
# ['raju', 'radha', 'dolu', 'ramu', 'bolu']

# %% [markdown]
# APPEND

# %%
list1.append('shinas')

# %%
list1
# Out:
# ['raju', 'radha', 'dolu', 'ramu', 'bolu', 'shinas']

# %% [markdown]
# POP

# %%
list1 = ['raju','ramu','dolu','radha','bolu','shinas']

# %%
list1.pop()
# Out:
# 'shinas'

# %%
list1.pop(0)
# Out:
# 'raju'

# %%
list1
# Out:
# ['ramu', 'dolu', 'radha', 'bolu']

# %%
list1.remove('bolu')

# %%
list1
# Out:
# ['ramu', 'dolu', 'radha']

# %%
del list1[0]

# %%
list1
# Out:
# ['dolu', 'radha']

# %%
list1.pop()
# Out:
# 'dolu'

# %%
list1
# Out:
# ['raju', 'radha', 'dolu', 'ramu', 'bolu']

# %%
list1.pop(0)
# Out:
# 'raju'

# %%
list`

# %%
list1.remove('radha')

# %%
list1
# Out:
# ['dolu', 'ramu', 'bolu']

# %%
del list1[1]

# %%
list1
# Out:
# ['dolu', 'bolu']

# %%
list2 = [25,41,14,54,11,12,72,12]

# %%
list2.sort()

# %%
print(list2)
# Out:
# [11, 12, 12, 14, 25, 41, 54, 72]

# %%
list2 = [25,41,14,54,11,12,72,12]

# %%
list2.sort(reverse = True)

# %%
list2
# Out:
# [72, 54, 41, 25, 14, 12, 12, 11]

# %%
list2.reverse()

# %%
list2
# Out:
# [11, 12, 12, 14, 25, 41, 54, 72]

# %%
list2.sort()

# %%
list2
# Out:
# [11, 12, 12, 14, 25, 41, 54, 72]

# %%
list2.sort(reverse = True)

# %%
list2
# Out:
# [72, 54, 41, 25, 14, 12, 12, 11]

# %%
list2
# Out:
# [72, 54, 41, 25, 14, 12, 12, 11]

# %%
list2.reverse()

# %%
list2
# Out:
# [11, 12, 12, 14, 25, 41, 54, 72]

# %%
list2 = [25,41,14,54,11,12,72,12,25]

# %%
list2.count(25)
# Out:
# 2

# %%
list2.count(12)
# Out:
# 2

# %%
print(sum(list2))
# Out:
# 266

# %%
print(len(list2))
# Out:
# 9

# %%
print(max(list2))
# Out:
# 72

# %%
min(list2)
# Out:
# 11

# %%
len(list2)
# Out:
# 8

# %%
sum(list2)
# Out:
# 241

# %%
min(list2)
# Out:
# 11

# %%
max(list2)
# Out:
# 72
