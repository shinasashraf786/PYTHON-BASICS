# %% [markdown]
# Collection data type is like a container used to store multiple data items

# %% [markdown]
# List

# %% [markdown]
# List is a ordered sequence
#
# List is a mutable collection of data
#
# Theoritically of infinite length
#
# iterable
#
# allow duplicate members
#
# return with square brackets

# %%
list = ['shinas','raju','sarang',4,5,7,2,2.0]

# %%
print(list)
# Out:
# ['shinas', 'raju', 'sarang', 4, 5, 7, 2, 2.0]

# %%
#list = [['shinas',24],'ajay','sanay',19.0,11,'ajay']

# %%
list1 = ['raju','ramu','dolu','bolu',10,21]

# %%
print(list1)
# Out:
# ['raju', 'ramu', 'dolu', 'bolu', 10, 21]

# %%
list1 = list(['raju','ramu','dolu','bolu',10,21,'sarath'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-b85b39181b08> in <cell line: 1>()
# ----> 1 list1 = list(['raju','ramu','dolu','bolu',10,21,'sarath'])
#
# TypeError: 'list' object is not callable

# %%
list1
# Out:
# ['raju', 'ramu', 'dolu', 'bolu', 10, 21]

# %% [markdown]
# **Nested List**

# %%
list1 = [['raju',30],['ramu'],'dolu','bolu',10,21]

# %%
list1
# Out:
# [['raju', 30], ['ramu'], 'dolu', 'bolu', 10, 21]
