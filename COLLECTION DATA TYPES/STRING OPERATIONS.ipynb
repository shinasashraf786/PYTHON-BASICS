# %%
string1 = 'hello how are you'

# %%
print(string1.find('how'))
# Out:
# 6

# %%
print(string1.find('how',1,9))
# Out:
# 6

# %%
print(string1.find('how',1,8))
# Out:
# -1

# %%
string1 = 'hello how are you raju'

# %%
print(string1.find('raju'))
# Out:
# 18

# %%
print(string1.rfind('raju'))
# Out:
# 18

# %%
print(string1.rfind('raju',1,22))
# Out:
# 18

# %%
stringlist = string1.split(' ')

# %%
print(stringlist)
# Out:
# ['hello', 'how', 'are', 'you', 'raju']

# %% [markdown]
# String Join

# %%
string1 = ['hello','raju','how','are','you','raju']

stringlist = ' '.join(string1)

# %%
print(stringlist)
# Out:
# hello raju how are you raju

# %%
string1 = 'hello raju how are you'
string1 = string1.capitalize()

# %%
print(string1)
# Out:
# Hello raju how are you

# %%
string1 = 'hello raju how are you'
string1 = string1.upper()

# %%
string1
# Out:
# 'HELLO RAJU HOW ARE YOU'

# %%
string1 = 'hello raju how are you'
string1 = string1.lower()

# %%
string1
# Out:
# 'hello raju how are you'

# %%
string1 = 'hello raju how are you'
string1 = string1.title()

# %%
string1
# Out:
# 'Hello Raju How Are You'

# %%
string1 = '12hello raju how are you'
string1 = string1.isalnum()
print(string1)
# Out:
# False

# %%
txt = "12Company"

x = txt.isalnum()

print(x)
# Out:
# False

# %%
string1 = 'hellorajuhowareyou8798'
string1 = string1.isalnum()
print(string1)
# Out:
# True

# %%
string1 = 'hello raju how are you'
string1 = string1.istitle()
print(string1)
# Out:
# False

# %%
string1 = 'hello raju how are you'
string1 = string1.isdigit()
print(string1)
# Out:
# False

# %%
string1 = 'hello raju how are you'
string1 = string1.islower()
print(string1)
# Out:
# True

# %%
string1 = 'hello raju how are you'
string1 = string1.isupper()
print(string1)
# Out:
# False

# %%
#user input

#age = 80

age = int(input('enter your age : '))
float = float(input('enter your age : '))
print(float)
print(type(float))

print(age)
print(type(age))
# Out:
# enter your age : 21
# enter your age : 12
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-8d7930327cff> in <cell line: 6>()
#       4
#       5 age = int(input('enter your age : '))
# ----> 6 float = float(input('enter your age : '))
#       7 print(float)
#       8 print(type(float))
#
# TypeError: 'float' object is not callable

# %%
age = 80
age = int(input('enter your age : '))
print(age)
print(type(age))


age1 = float(input('enter your age : '))
print(age1)
print(type(float))
# Out:
# enter your age : 21
# 21
# <class 'int'>
# enter your age : 12
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-4f1993334966> in <cell line: 7>()
#       5
#       6
# ----> 7 age1 = float(input('enter your age : '))
#       8 print(age1)
#       9 print(type(float))
#
# TypeError: 'float' object is not callable

# %%
#conditions

#used to decide the path of exectuion
