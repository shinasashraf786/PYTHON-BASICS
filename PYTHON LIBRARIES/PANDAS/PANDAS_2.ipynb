# %%
#read_csv

import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/Pandas/expor_dataframe.csv")

print(df)
# Out:
#          Label  maths  english
# 0  ENGINEERING    3.0        4
# 1         MBBS    NaN        6
# 2         ARTS    7.0        8
# 3    MALAYALAM    NaN        4

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("/content/drive/MyDrive/Pandas/expor_dataframe.csv",index_col=["Label"])

df
# Out:
#              maths  english
# Label
# ENGINEERING    3.0        4
# MBBS           NaN        6
# ARTS           7.0        8
# MALAYALAM      NaN        4

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("/content/drive/MyDrive/Pandas/expor_dataframe.csv",dtype={"english":np.float64})

df
# Out:
#          Label  maths  english
# 0  ENGINEERING    3.0      4.0
# 1         MBBS    NaN      6.0
# 2         ARTS    7.0      8.0
# 3    MALAYALAM    NaN      4.0

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("/content/drive/MyDrive/Pandas/expor_dataframe.csv",names=["A","B","C"],header=0)

df
# Out:
#              A    B  C
# 0  ENGINEERING  3.0  4
# 1         MBBS  NaN  6
# 2         ARTS  7.0  8
# 3    MALAYALAM  NaN  4

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("/content/drive/MyDrive/Pandas/expor_dataframe.csv",usecols=["maths","english"])

df
# Out:
#    maths  english
# 0    3.0        4
# 1    NaN        6
# 2    7.0        8
# 3    NaN        4

# %%
df.to_csv('marks.csv')

# %%
#to_csv

import pandas as pd

two = pd.DataFrame({"id":[1,2,3,4,5],'Name':['Billy','Brian','Bran','Bryce','Betty',],'subject_id':['sub2','sub4','sub3','sub6','sub5'],'Marks_scored':[89,80,79,97,88]},index=[1,2,3,4,5])
three = pd.DataFrame({"id":[1,2,3,4,5],'Name':['Billy','Brian','Bran','Bryce','Betty',],'subject_id':['sub2','sub4','sub3','sub6','sub5'],'Marks_scored':[89,80,79,97,88],'roll no':[1,23,4,5,5,]},index=[1,2,3,4,5,])

df=pd.concat([two,three])

df
# Out:
#    id   Name subject_id  Marks_scored  roll no
# 1   1  Billy       sub2            89      NaN
# 2   2  Brian       sub4            80      NaN
# 3   3   Bran       sub3            79      NaN
# 4   4  Bryce       sub6            97      NaN
# 5   5  Betty       sub5            88      NaN
# 1   1  Billy       sub2            89      1.0
# 2   2  Brian       sub4            80     23.0
# 3   3   Bran       sub3            79      4.0
# 4   4  Bryce       sub6            97      5.0
# 5   5  Betty       sub5            88      5.0

# %%
import pandas as pd
two = pd.DataFrame({'id':[1,2,3,4,5,7],'Name':['Billy','Brian','Bran','Bryce','Betty','ramu'],'subject_id':['sub2','sub4','sub8','sub6','sub5','sub9'],'Marks_scored':[89,80,79,97,88,56],'class':[1,23,4,5,5,6]},index=[1,2,3,4,5,7])
three = pd.DataFrame({'id':[1,2,3,4,5,6],'Name':['Billy','Brian','Bran','Bryce','Betty','sarang'],'subject_id':['sub2','sub4','sub3','sub6','sub5','sub7'],'Marks_scored':[89,80,79,97,88,76],'roll no':[1,23,4,5,5,6]},index=[1,2,3,4,5,6])
df
# Out:
#    id   Name subject_id  Marks_scored  roll no
# 1   1  Billy       sub2            89      NaN
# 2   2  Brian       sub4            80      NaN
# 3   3   Bran       sub3            79      NaN
# 4   4  Bryce       sub6            97      NaN
# 5   5  Betty       sub5            88      NaN
# 1   1  Billy       sub2            89      1.0
# 2   2  Brian       sub4            80     23.0
# 3   3   Bran       sub3            79      4.0
# 4   4  Bryce       sub6            97      5.0
# 5   5  Betty       sub5            88      5.0

# %%
df.to_csv('student.csv')

# %%
df1 = pd.read_csv('student.csv')
df1
# Out:
#    Unnamed: 0  id   Name subject_id  Marks_scored  roll no
# 0           1   1  Billy       sub2            89      NaN
# 1           2   2  Brian       sub4            80      NaN
# 2           3   3   Bran       sub3            79      NaN
# 3           4   4  Bryce       sub6            97      NaN
# 4           5   5  Betty       sub5            88      NaN
# 5           1   1  Billy       sub2            89      1.0
# 6           2   2  Brian       sub4            80     23.0
# 7           3   3   Bran       sub3            79      4.0
# 8           4   4  Bryce       sub6            97      5.0
# 9           5   5  Betty       sub5            88      5.0

# %%
df1.isna().any()
# Out:
# Unnamed: 0      False
# id              False
# Name            False
# subject_id      False
# Marks_scored    False
# roll no          True
# dtype: bool

# %%
df1.isna().any().sum()
# Out:
# 1

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0      0
# id              0
# Name            0
# subject_id      0
# Marks_scored    0
# roll no         5
# dtype: int64

# %%
df1.isnull().sum()*100/len(df)
# Out:
# Unnamed: 0       0.0
# id               0.0
# Name             0.0
# subject_id       0.0
# Marks_scored     0.0
# roll no         50.0
# dtype: float64

# %%
df1
# Out:
#    Unnamed: 0  id   Name subject_id  Marks_scored  roll no
# 0           1   1  Billy       sub2            89      NaN
# 1           2   2  Brian       sub4            80      NaN
# 2           3   3   Bran       sub3            79      NaN
# 3           4   4  Bryce       sub6            97      NaN
# 4           5   5  Betty       sub5            88      NaN
# 5           1   1  Billy       sub2            89      1.0
# 6           2   2  Brian       sub4            80     23.0
# 7           3   3   Bran       sub3            79      4.0
# 8           4   4  Bryce       sub6            97      5.0
# 9           5   5  Betty       sub5            88      5.0

# %%
mean = df1['roll no'].mean()

# %%
df1['class'].fillna(mean,inplace=True)
df1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'class'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df1.dropna()

df1
# Out:
#    Unnamed: 0  id   Name subject_id  Marks_scored  roll no
# 0           1   1  Billy       sub2            89      NaN
# 1           2   2  Brian       sub4            80      NaN
# 2           3   3   Bran       sub3            79      NaN
# 3           4   4  Bryce       sub6            97      NaN
# 4           5   5  Betty       sub5            88      NaN
# 5           1   1  Billy       sub2            89      1.0
# 6           2   2  Brian       sub4            80     23.0
# 7           3   3   Bran       sub3            79      4.0
# 8           4   4  Bryce       sub6            97      5.0
# 9           5   5  Betty       sub5            88      5.0

# %%
df1 = pd.read_csv('student.csv')
df1
# Out:
#    Unnamed: 0  id   Name subject_id  Marks_scored  roll no
# 0           1   1  Billy       sub2            89      NaN
# 1           2   2  Brian       sub4            80      NaN
# 2           3   3   Bran       sub3            79      NaN
# 3           4   4  Bryce       sub6            97      NaN
# 4           5   5  Betty       sub5            88      NaN
# 5           1   1  Billy       sub2            89      1.0
# 6           2   2  Brian       sub4            80     23.0
# 7           3   3   Bran       sub3            79      4.0
# 8           4   4  Bryce       sub6            97      5.0
# 9           5   5  Betty       sub5            88      5.0

# %%
df.ffill()
# Out:
#    id   Name subject_id  Marks_scored  roll no
# 1   1  Billy       sub2            89      NaN
# 2   2  Brian       sub4            80      NaN
# 3   3   Bran       sub3            79      NaN
# 4   4  Bryce       sub6            97      NaN
# 5   5  Betty       sub5            88      NaN
# 1   1  Billy       sub2            89      1.0
# 2   2  Brian       sub4            80     23.0
# 3   3   Bran       sub3            79      4.0
# 4   4  Bryce       sub6            97      5.0
# 5   5  Betty       sub5            88      5.0

# %% [markdown]
# Pandas Time Series
#
# we can find out the data within a certain range of date and
#
# time by using pandas module named Time series
#
# ---
# --Equivalent to date time python package
#
# --Used to deal with date time
#
# --Complex operation on date time can be done

# %% [markdown]
# TimeStamp
#
#  21-Jan-2021
#
#  21-01-2021
#
#  21-01-21
#
#  21-01-2021 30:12:11

# %%
data = '15-january-2023'

# %%
type(data)
# Out:
# str

# %%
import pandas as pd

dt = pd.to_datetime(data,format='%d-%B-%Y')

# %%
dt
# Out:
# Timestamp('2023-01-15 00:00:00')

# %%
type(dt)
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# %d 01,22,23

# %%
# %B january,march
# %bjan,mar
# %m - int (month in integer)

# %%
# %y 20,21
# %Y 2020,2021
# %H----24hr

# %I---12hr
# %M---minute
# %S----seconds

# %%
dates = ['2020-11-25 2:30:00 PM', 'jan 5,2020 18:45:00','01/11/2020','2020.01.11','2020/01/11','20201105']

import pandas as pd

date_time = pd.to_datetime(dates)

date_time
# Out:
# DatetimeIndex(['2020-11-25 14:30:00', '2020-01-05 18:45:00',
#                '2020-01-11 00:00:00', '2020-01-11 00:00:00',
#                '2020-01-11 00:00:00', '2020-11-05 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
import pandas as pd

dates = '11-jan-20'

date_time = pd.to_datetime(dates)

print(date_time)

print(date_time.day)

print(date_time.week)
print(date_time.day_of_week)
print(date_time.dayofyear)
print(date_time.minute)
print(date_time.is_leap_year)
print(date_time.is_month_end)
print(date_time.is_month_start)
print(date_time.month)

print(date_time.quarter)
# Out:
# 2020-01-11 00:00:00
# 11
# 2
# 5
# 11
# 0
# True
# False
# False
# 1
# 1

# %%
df = pd.read_csv('/content/drive/MyDrive/DATA SCIENCE-MAIN/PYTHON-DATA SCIENCE/LIBRARIES/PANDAS/shirpurGoldRefinery (1).csv')

df.head(2)
# Out:
#                Date  Open Price  High Price  Low Price  Close Price  \
# 0  29-December-2017      203.55       206.5     201.00       201.85
# 1  28-December-2017      202.00       207.6     199.55       202.80
#
#           WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# 0  202.760380          3372             68              683708.0
# 1  203.118439          8612            196             1749256.0
#
#    Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# 0                  2202                      65.30             5.50
# 1                  5063                      58.79             8.05
#
#    Spread Close-Open
# 0               -1.7
# 1                0.8

# %%
df.iat[0,0]
# Out:
# '29-December-2017'

# %%
type(df.iat[0,0])
# Out:
# str

# %%
df['TimeStamp']=pd.to_datetime(df['Date'])

# %%
df.head(2)
# Out:
#                Date  Open Price  High Price  Low Price  Close Price  \
# 0  29-December-2017      203.55       206.5     201.00       201.85
# 1  28-December-2017      202.00       207.6     199.55       202.80
#
#           WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# 0  202.760380          3372             68              683708.0
# 1  203.118439          8612            196             1749256.0
#
#    Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# 0                  2202                      65.30             5.50
# 1                  5063                      58.79             8.05
#
#    Spread Close-Open  TimeStamp
# 0               -1.7 2017-12-29
# 1                0.8 2017-12-28

# %%
df.iat[0,13]
# Out:
# Timestamp('2017-12-29 00:00:00')

# %%
type(df.iat[0,13])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df
# Out:
#           Date  Open Price  High Price  Low Price  Close Price         WAP  \
# 0   2017-12-29      203.55       206.5     201.00       201.85  202.760380
# 1   2017-12-28      202.00       207.6     199.55       202.80  203.118439
# 2   2017-12-27      209.10       213.6     195.20       197.80  202.801825
# 3   2017-12-26      216.50       219.9     207.20       209.70  213.418007
# 4   2017-12-22      218.95       233.6     212.40       218.15  223.089049
# ..         ...         ...         ...        ...          ...         ...
# 243 2017-01-06      110.10       110.1     107.80       110.10  110.048719
# 244 2017-01-05      101.00       104.9     100.00       104.90  103.352347
# 245 2017-01-04       99.50       102.0      99.50        99.95  100.293226
# 246 2017-01-03      102.00       102.0     100.05       100.65  100.784909
# 247 2017-01-02      104.00       104.0      99.00       101.65  101.302024
#
# ...

# %%
df.TimeStamp
# Out:
# 0     2017-12-29
# 1     2017-12-28
# 2     2017-12-27
# 3     2017-12-26
# 4     2017-12-22
#          ...
# 243   2017-01-06
# 244   2017-01-05
# 245   2017-01-04
# 246   2017-01-03
# 247   2017-01-02
# Name: TimeStamp, Length: 248, dtype: datetime64[ns]

# %%
df.TimeStamp.max()
# Out:
# Timestamp('2017-12-29 00:00:00')

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/content/drive/MyDrive/DATA SCIENCE-MAIN/PYTHON-DATA SCIENCE/LIBRARIES/PANDAS/shirpurGoldRefinery (1).csv')

# %%
df.head()
# Out:
#                Date  Open Price  High Price  Low Price  Close Price  \
# 0  29-December-2017      203.55       206.5     201.00       201.85
# 1  28-December-2017      202.00       207.6     199.55       202.80
# 2  27-December-2017      209.10       213.6     195.20       197.80
# 3  26-December-2017      216.50       219.9     207.20       209.70
# 4  22-December-2017      218.95       233.6     212.40       218.15
#
#           WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# 0  202.760380          3372             68              683708.0
# 1  203.118439          8612            196             1749256.0
# 2  202.801825         24983            426             5066598.0
# 3  213.418007         17782            363             3794999.0
# 4  223.089049        165976           2710            37027428.0
#
#    Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# 0                  2202                      65.30             5.50
# ...

# %%
df['Date'] = pd. to_datetime(df['Date'],format='%d-%B-%Y')

# %%
df.head(2)
# Out:
#         Date  Open Price  High Price  Low Price  Close Price         WAP  \
# 0 2017-12-29      203.55       206.5     201.00       201.85  202.760380
# 1 2017-12-28      202.00       207.6     199.55       202.80  203.118439
#
#    No.of Shares  No. of Trades  Total Turnover (Rs.)  Deliverable Quantity  \
# 0          3372             68              683708.0                  2202
# 1          8612            196             1749256.0                  5063
#
#    % Deli. Qty to Traded Qty  Spread High-Low  Spread Close-Open
# 0                      65.30             5.50               -1.7
# 1                      58.79             8.05                0.8

# %%
df['day'] = pd.DatetimeIndex(df['Date']).day
df['year'] = pd.DatetimeIndex(df['Date']).year
df['month'] = pd.DatetimeIndex(df['Date']).month

# %%
df.head()
# Out:
#         Date  Open Price  High Price  Low Price  Close Price         WAP  \
# 0 2017-12-29      203.55       206.5     201.00       201.85  202.760380
# 1 2017-12-28      202.00       207.6     199.55       202.80  203.118439
# 2 2017-12-27      209.10       213.6     195.20       197.80  202.801825
# 3 2017-12-26      216.50       219.9     207.20       209.70  213.418007
# 4 2017-12-22      218.95       233.6     212.40       218.15  223.089049
#
#    No.of Shares  No. of Trades  Total Turnover (Rs.)  Deliverable Quantity  \
# 0          3372             68              683708.0                  2202
# 1          8612            196             1749256.0                  5063
# 2         24983            426             5066598.0                 14168
# 3         17782            363             3794999.0                  7540
# 4        165976           2710            37027428.0                 60121
#
# ...
