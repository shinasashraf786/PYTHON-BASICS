# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#read_csv

import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/DATA SCIENCE-MAIN/PYTHON-DATA SCIENCE/LIBRARIES/PANDAS/expor_dataframe.csv')

# %%
df
# Out:
#          Label  maths  english
# 0  ENGINEERING    3.0        4
# 1         MBBS    NaN        6
# 2         ARTS    7.0        8
# 3    MALAYALAM    NaN        4

# %%
#read_csv

import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/DATA SCIENCE-MAIN/PYTHON-DATA SCIENCE/LIBRARIES/PANDAS/expor_dataframe.csv',skiprows=2)

df
# Out:
#         MBBS  Unnamed: 1  6
# 0       ARTS         7.0  8
# 1  MALAYALAM         NaN  4

# %%
#read_csv

import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/DATA SCIENCE-MAIN/PYTHON-DATA SCIENCE/LIBRARIES/PANDAS/expor_dataframe.csv',index_col=['Label'])

# %%
df
# Out:
#              maths  english
# Label
# ENGINEERING    3.0        4
# MBBS           NaN        6
# ARTS           7.0        8
# MALAYALAM      NaN        4

# %%
#read_csv

import pandas as pd
import numpy as np

df = pd.read_csv('/content/drive/MyDrive/DATA SCIENCE-MAIN/PYTHON-DATA SCIENCE/LIBRARIES/PANDAS/expor_dataframe.csv',dtype={'english':np.float64})

# %%
df
# Out:
#          Label  maths  english
# 0  ENGINEERING    3.0      4.0
# 1         MBBS    NaN      6.0
# 2         ARTS    7.0      8.0
# 3    MALAYALAM    NaN      4.0

# %%
#read_csv

import pandas as pd
import numpy as np

df = pd.read_csv('/content/drive/MyDrive/DATA SCIENCE-MAIN/PYTHON-DATA SCIENCE/LIBRARIES/PANDAS/expor_dataframe.csv',index_col=['Label'])

df
# Out:
#              maths  english
# Label
# ENGINEERING    3.0        4
# MBBS           NaN        6
# ARTS           7.0        8
# MALAYALAM      NaN        4

# %%
#read_csv

import pandas as pd
import numpy as np

df = pd.read_csv('/content/drive/MyDrive/DATA SCIENCE-MAIN/PYTHON-DATA SCIENCE/LIBRARIES/PANDAS/expor_dataframe.csv',dtype={'english':np.float64})

df
# Out:
#          Label  maths  english
# 0  ENGINEERING    3.0      4.0
# 1         MBBS    NaN      6.0
# 2         ARTS    7.0      8.0
# 3    MALAYALAM    NaN      4.0

# %%
#read_csv

import pandas as pd
import numpy as np

df = pd.read_csv('/content/drive/MyDrive/DATA SCIENCE-MAIN/PYTHON-DATA SCIENCE/LIBRARIES/PANDAS/expor_dataframe.csv',names=["A","B","C"])

df
# Out:
#              A      B        C
# 0        Label  maths  english
# 1  ENGINEERING      3        4
# 2         MBBS    NaN        6
# 3         ARTS      7        8
# 4    MALAYALAM    NaN        4

# %%
#read_csv

import pandas as pd
import numpy as np

df = pd.read_csv('/content/drive/MyDrive/DATA SCIENCE-MAIN/PYTHON-DATA SCIENCE/LIBRARIES/PANDAS/expor_dataframe.csv',names=["A","B","C"],header=0)

df
# Out:
#              A    B  C
# 0  ENGINEERING  3.0  4
# 1         MBBS  NaN  6
# 2         ARTS  7.0  8
# 3    MALAYALAM  NaN  4

# %%
#read_csv

import pandas as pd
import numpy as np

df = pd.read_csv('/content/drive/MyDrive/DATA SCIENCE-MAIN/PYTHON-DATA SCIENCE/LIBRARIES/PANDAS/expor_dataframe.csv',usecols=['maths','english'])

df
# Out:
#    maths  english
# 0    3.0        4
# 1    NaN        6
# 2    7.0        8
# 3    NaN        4

# %%
#to_csv

import pandas as pd
two = pd.DataFrame({'id':[1,2,3,4,5,7],'Name':['Billy','Brian','Bran','Bryce','Betty','ramu'],'subject_id':['sub2','sub4','sub8','sub6','sub5','sub9'],'Marks_scored':[89,80,79,97,88,56],'class':[1,23,4,5,5,6]},index=[1,2,3,4,5,7])

three = pd.DataFrame({'id':[1,2,3,4,5,6],'Name':['Billy','Brian','Bran','Bryce','Betty','sarang'],'subject_id':['sub2','sub4','sub3','sub6','sub5','sub7'],'Marks_scored':[89,80,79,97,88,76],'roll no':[1,23,4,5,5,6]},index=[1,2,3,4,5,6])

# %%
df = pd.concat([three,two])

# %%
df
# Out:
#    id    Name subject_id  Marks_scored  roll no  class
# 1   1   Billy       sub2            89      1.0    NaN
# 2   2   Brian       sub4            80     23.0    NaN
# 3   3    Bran       sub3            79      4.0    NaN
# 4   4   Bryce       sub6            97      5.0    NaN
# 5   5   Betty       sub5            88      5.0    NaN
# 6   6  sarang       sub7            76      6.0    NaN
# 1   1   Billy       sub2            89      NaN    1.0
# 2   2   Brian       sub4            80      NaN   23.0
# 3   3    Bran       sub8            79      NaN    4.0
# 4   4   Bryce       sub6            97      NaN    5.0
# 5   5   Betty       sub5            88      NaN    5.0
# 7   7    ramu       sub9            56      NaN    6.0

# %%
df.to_csv('student.csv')

# %%
df1 = pd.read_csv('student.csv')

df1
# Out:
#     Unnamed: 0  id    Name subject_id  Marks_scored  roll no  class
# 0            1   1   Billy       sub2            89      1.0    NaN
# 1            2   2   Brian       sub4            80     23.0    NaN
# 2            3   3    Bran       sub3            79      4.0    NaN
# 3            4   4   Bryce       sub6            97      5.0    NaN
# 4            5   5   Betty       sub5            88      5.0    NaN
# 5            6   6  sarang       sub7            76      6.0    NaN
# 6            1   1   Billy       sub2            89      NaN    1.0
# 7            2   2   Brian       sub4            80      NaN   23.0
# 8            3   3    Bran       sub8            79      NaN    4.0
# 9            4   4   Bryce       sub6            97      NaN    5.0
# 10           5   5   Betty       sub5            88      NaN    5.0
# 11           7   7    ramu       sub9            56      NaN    6.0

# %%
df1.isna()
# Out:
#     Unnamed: 0     id   Name  subject_id  Marks_scored  roll no  class
# 0        False  False  False       False         False    False   True
# 1        False  False  False       False         False    False   True
# 2        False  False  False       False         False    False   True
# 3        False  False  False       False         False    False   True
# 4        False  False  False       False         False    False   True
# 5        False  False  False       False         False    False   True
# 6        False  False  False       False         False     True  False
# 7        False  False  False       False         False     True  False
# 8        False  False  False       False         False     True  False
# 9        False  False  False       False         False     True  False
# 10       False  False  False       False         False     True  False
# 11       False  False  False       False         False     True  False

# %%
df1.isna().any()
# Out:
# Unnamed: 0      False
# id              False
# Name            False
# subject_id      False
# Marks_scored    False
# roll no          True
# class            True
# dtype: bool

# %%
df1.isna().any().sum()
# Out:
# 2

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0      0
# id              0
# Name            0
# subject_id      0
# Marks_scored    0
# roll no         6
# class           6
# dtype: int64

# %%
df1.isnull().sum()*100/len(df)
# Out:
# Unnamed: 0       0.0
# id               0.0
# Name             0.0
# subject_id       0.0
# Marks_scored     0.0
# roll no         50.0
# class           50.0
# dtype: float64

# %%
df1.fillna(5)
# Out:
#     Unnamed: 0  id    Name subject_id  Marks_scored  roll no  class
# 0            1   1   Billy       sub2            89      1.0    5.0
# 1            2   2   Brian       sub4            80     23.0    5.0
# 2            3   3    Bran       sub3            79      4.0    5.0
# 3            4   4   Bryce       sub6            97      5.0    5.0
# 4            5   5   Betty       sub5            88      5.0    5.0
# 5            6   6  sarang       sub7            76      6.0    5.0
# 6            1   1   Billy       sub2            89      5.0    1.0
# 7            2   2   Brian       sub4            80      5.0   23.0
# 8            3   3    Bran       sub8            79      5.0    4.0
# 9            4   4   Bryce       sub6            97      5.0    5.0
# 10           5   5   Betty       sub5            88      5.0    5.0
# 11           7   7    ramu       sub9            56      5.0    6.0

# %%
df1 = pd.read_csv('student.csv')

df1
# Out:
#     Unnamed: 0  id    Name subject_id  Marks_scored  roll no  class
# 0            1   1   Billy       sub2            89      1.0    NaN
# 1            2   2   Brian       sub4            80     23.0    NaN
# 2            3   3    Bran       sub3            79      4.0    NaN
# 3            4   4   Bryce       sub6            97      5.0    NaN
# 4            5   5   Betty       sub5            88      5.0    NaN
# 5            6   6  sarang       sub7            76      6.0    NaN
# 6            1   1   Billy       sub2            89      NaN    1.0
# 7            2   2   Brian       sub4            80      NaN   23.0
# 8            3   3    Bran       sub8            79      NaN    4.0
# 9            4   4   Bryce       sub6            97      NaN    5.0
# 10           5   5   Betty       sub5            88      NaN    5.0
# 11           7   7    ramu       sub9            56      NaN    6.0

# %%
mean = df1['class'].mean()

# %%
mean
# Out:
# 7.333333333333333

# %%
df1['class'].fillna(mean,inplace=True)

df1
# Out:
#     Unnamed: 0  id    Name subject_id  Marks_scored  roll no      class
# 0            1   1   Billy       sub2            89      1.0   7.333333
# 1            2   2   Brian       sub4            80     23.0   7.333333
# 2            3   3    Bran       sub3            79      4.0   7.333333
# 3            4   4   Bryce       sub6            97      5.0   7.333333
# 4            5   5   Betty       sub5            88      5.0   7.333333
# 5            6   6  sarang       sub7            76      6.0   7.333333
# 6            1   1   Billy       sub2            89      NaN   1.000000
# 7            2   2   Brian       sub4            80      NaN  23.000000
# 8            3   3    Bran       sub8            79      NaN   4.000000
# 9            4   4   Bryce       sub6            97      NaN   5.000000
# 10           5   5   Betty       sub5            88      NaN   5.000000
# 11           7   7    ramu       sub9            56      NaN   6.000000

# %%
df1 = df1.dropna()

df1
# Out:
#    Unnamed: 0  id    Name subject_id  Marks_scored  roll no     class
# 0           1   1   Billy       sub2            89      1.0  7.333333
# 1           2   2   Brian       sub4            80     23.0  7.333333
# 2           3   3    Bran       sub3            79      4.0  7.333333
# 3           4   4   Bryce       sub6            97      5.0  7.333333
# 4           5   5   Betty       sub5            88      5.0  7.333333
# 5           6   6  sarang       sub7            76      6.0  7.333333

# %%
df1 = pd.read_csv('student.csv')

df1
# Out:
#     Unnamed: 0  id    Name subject_id  Marks_scored  roll no  class
# 0            1   1   Billy       sub2            89      1.0    NaN
# 1            2   2   Brian       sub4            80     23.0    NaN
# 2            3   3    Bran       sub3            79      4.0    NaN
# 3            4   4   Bryce       sub6            97      5.0    NaN
# 4            5   5   Betty       sub5            88      5.0    NaN
# 5            6   6  sarang       sub7            76      6.0    NaN
# 6            1   1   Billy       sub2            89      NaN    1.0
# 7            2   2   Brian       sub4            80      NaN   23.0
# 8            3   3    Bran       sub8            79      NaN    4.0
# 9            4   4   Bryce       sub6            97      NaN    5.0
# 10           5   5   Betty       sub5            88      NaN    5.0
# 11           7   7    ramu       sub9            56      NaN    6.0

# %%
df1 = df.bfill()

df1
# Out:
#    id    Name subject_id  Marks_scored  roll no  class
# 1   1   Billy       sub2            89      1.0    1.0
# 2   2   Brian       sub4            80     23.0    1.0
# 3   3    Bran       sub3            79      4.0    1.0
# 4   4   Bryce       sub6            97      5.0    1.0
# 5   5   Betty       sub5            88      5.0    1.0
# 6   6  sarang       sub7            76      6.0    1.0
# 1   1   Billy       sub2            89      NaN    1.0
# 2   2   Brian       sub4            80      NaN   23.0
# 3   3    Bran       sub8            79      NaN    4.0
# 4   4   Bryce       sub6            97      NaN    5.0
# 5   5   Betty       sub5            88      NaN    5.0
# 7   7    ramu       sub9            56      NaN    6.0

# %%
df1 = df.ffill()

df1
# Out:
#    id    Name subject_id  Marks_scored  roll no  class
# 1   1   Billy       sub2            89      1.0    NaN
# 2   2   Brian       sub4            80     23.0    NaN
# 3   3    Bran       sub3            79      4.0    NaN
# 4   4   Bryce       sub6            97      5.0    NaN
# 5   5   Betty       sub5            88      5.0    NaN
# 6   6  sarang       sub7            76      6.0    NaN
# 1   1   Billy       sub2            89      6.0    1.0
# 2   2   Brian       sub4            80      6.0   23.0
# 3   3    Bran       sub8            79      6.0    4.0
# 4   4   Bryce       sub6            97      6.0    5.0
# 5   5   Betty       sub5            88      6.0    5.0
# 7   7    ramu       sub9            56      6.0    6.0
