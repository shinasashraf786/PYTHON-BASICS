# %% [markdown]
# **DATA TYPES IN PYTHON**

# %% [markdown]
# #text type - str

# %%
name = 'sj'
print(name)
# Out:
# sj

# %%
name = 'shinas'

# %%
print(name)
# Out:
# sj

# %%
type(name)
# Out:
# str

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
name = '11'
print(name)     #if inside qoutes it will consider as string
# Out:
# 11

# %%
type(name)
# Out:
# str

# %%
name = "22"

# %%
print(name)
# Out:
# 22

# %%
name = """shinas"""

# %%
print(name)
# Out:
# shinas

# %%
name = '''faiz'''

# %%
print(name)
# Out:
# faiz

# %%
name = """vada11 daad asdsdas fasdksadandsad
        sadsdadas;fnffdsfadjkjnnjnkfmfffdp"""         #for printing multiple lines of code

# %%
print(name)
# Out:
# vada11 daad asdsdas fasdksadandsad
#         sadsdadas;fnffdsfadjkjnnjnkfmfffdp

# %% [markdown]
# **NUMERIC TYPE**

# %% [markdown]
# INTEGER.  -int
#
# FLOAT    -float
#
# COMPLEX. -

# %% [markdown]
# **INTEGER**

# %%
age = 90

# %%
print(age)
# Out:
# 90

# %%
type(age)
# Out:
# int

# %%
print(type(age))
# Out:
# <class 'int'>

# %% [markdown]
# **FLOAT**

# %%
age = 90.5

# %%
print(type(age))
# Out:
# <class 'float'>

# %% [markdown]
# **COMPLEX**

# %%
age = 90+5j

# %%
print(type(age))
# Out:
# <class 'complex'>

# %%
print(age.real)
# Out:
# 90.0

# %%
print(age.imag)
# Out:
# 5.0

# %% [markdown]
# **SEQUENCE TYPE**    (COLLECTION OF DATA)

# %% [markdown]
# LIST,TUPLE,RANGE

# %% [markdown]
# **MAPPING TYPES**

# %% [markdown]
# #dict       (collection of data)

# %%
dict1 = {name:'sanay',age:23,name:'shinas',age:21}

# %%
print(dict1)
# Out:
# vada11 daad asdsdas fasdksadandsad
#         sadsdadas;fnffdsfadjkjnnjnkfmfffdp

# %%
dict2 = {name:'shinas',age:23}

# %%
dict2
# Out:
# {'vada11 daad asdsdas fasdksadandsad\n        sadsdadas;fnffdsfadjkjnnjnkfmfffdp': 'shinas',
#  (90+5j): 23}

# %% [markdown]
# dict1 = {age:23,name:'shinas'}

# %% [markdown]
# **Set Types**

# %% [markdown]
# 1 - Set
#
# 2 - Frozen Set

# %% [markdown]
# BOOLEAN DATA TYPES
#
#
# TRUE
#
# FALSE

# %%
x = True

# %%
print(type(x))
# Out:
# <class 'bool'>

# %%
print(True+True)
# Out:
# 2

# %%
print(False+False)
# Out:
# 0

# %%
print(True+True+False)
# Out:
# 2

# %% [markdown]
# **NONE TYPE**

# %%
x = None
print(x)
# Out:
# None

# %%
print(type(x))
# Out:
# <class 'NoneType'>
