# %% [markdown]
# **Data type Casting**

# %%
age = 19

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
age = str(age)

# %%
print(type(age))
# Out:
# <class 'str'>

# %%
print(age)
# Out:
# 19

# %%
print(type(age))
# Out:
# <class 'str'>

# %%
age = float(age)

# %%
print(type(age))
# Out:
# <class 'float'>

# %%
print(age)
# Out:
# 19.0

# %%
age = 10

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
age1 = float(age)

# %%
print(type(age1))
# Out:
# <class 'float'>

# %%
age1
# Out:
# 10.0

# %%
age = 23.5

# %%
age = int(age)

# %%
age
# Out:
# 23

# %% [markdown]
# int,float to str

# %%
num = 12.90

# %%
print(num)
# Out:
# 12.9

# %%
print(type(num))
# Out:
# <class 'float'>

# %%
num1 = str(num)

# %%
print(num1)
# Out:
# 12.9

# %%
print(type(num1))
# Out:
# <class 'str'>

# %%
num2 = int(num)

# %%
num2
# Out:
# 12

# %%
age = 18

# %%
age
# Out:
# 18

# %%
age1 = complex(age)

# %%
age1
# Out:
# (18+0j)

# %%
age1.real
# Out:
# 18.0

# %%
age1.imag
# Out:
# 0.0

# %%
print(type(age1))
# Out:
# <class 'complex'>
